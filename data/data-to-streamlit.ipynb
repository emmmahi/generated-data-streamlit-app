# %%
import pandas as pd

# %%
data = pd.read_csv('07-24-data.csv')
data.head()
# Out:
#   Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0      mies   18        176.4        74.9  24.1                       2295
# 1      mies   18        181.7        97.9  29.7                       2712
# 2      mies   21        182.0       110.3  33.3                       2900
# 3      mies   24        183.6       134.9  40.0                       3300
# 4      mies   27        182.9        82.2  24.6                       2392
#
#    Rasvaprosentti  Rasvamassa (kg)  Rasvaton massa (kg)  Lihasmassa (kg)  \
# 0            17.5             13.1                 61.8             29.7
# 1            19.0             18.6                 79.3             40.0
# 2            30.0             33.1                 77.2             38.2
# 3            30.0             40.5                 94.4             43.3
# 4            25.4             20.9                 61.3             33.1
#
#    Lihasmassan osuus rasvattomasta  6min viitearvo  6min tulos  \
# ...

# %%
data = data.drop(labels=['6min viitearvo', 'testisyke/max syke', 'Kuntotaso vo2max (1-7)', 'kuntotaso kyykyt (1-5)'], axis=1)
data.head()
# Out:
#   Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0      mies   18        176.4        74.9  24.1                       2295
# 1      mies   18        181.7        97.9  29.7                       2712
# 2      mies   21        182.0       110.3  33.3                       2900
# 3      mies   24        183.6       134.9  40.0                       3300
# 4      mies   27        182.9        82.2  24.6                       2392
#
#    Rasvaprosentti  Rasvamassa (kg)  Rasvaton massa (kg)  Lihasmassa (kg)  \
# 0            17.5             13.1                 61.8             29.7
# 1            19.0             18.6                 79.3             40.0
# 2            30.0             33.1                 77.2             38.2
# 3            30.0             40.5                 94.4             43.3
# 4            25.4             20.9                 61.3             33.1
#
# ...

# %%
data.columns
# Out:
# Index(['Sukupuoli', 'Ikä', 'Pituus (cm)', 'Paino (kg)', 'BMI',
#        'Vuorokausiaineenvaihdunta', 'Rasvaprosentti', 'Rasvamassa (kg)',
#        'Rasvaton massa (kg)', 'Lihasmassa (kg)',
#        'Lihasmassan osuus rasvattomasta', '6min tulos', 'syke testin lopussa',
#        'vo2max', 'kyykyt/60s'],
#       dtype='object')

# %%
data
# Out:
#    Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0       mies   18        176.4        74.9  24.1                       2295
# 1       mies   18        181.7        97.9  29.7                       2712
# 2       mies   21        182.0       110.3  33.3                       2900
# 3       mies   24        183.6       134.9  40.0                       3300
# 4       mies   27        182.9        82.2  24.6                       2392
# 5       mies   33        178.2        71.2  22.4                       2137
# 6       mies   35        182.4        93.2  28.0                       2517
# 7       mies   37        177.5        75.1  23.8                       2170
# 8       mies   40        183.1        98.2  29.3                       2569
# 9       mies   40        174.6        71.5  23.5                       2071
# 10      mies   42        172.1        74.6  25.2                       2094
# ...

# %%
data.to_csv('08-08-streamlit-data.csv', index=False)
